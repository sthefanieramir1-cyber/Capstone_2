# %% [markdown]
# # Sales analyse over stores in	Maryland and New Jersey	in the terrytori of Northeast

# %%
pip install pandas

# %%
import pandas as pd

# %%
pf_sales = pd.read_csv("StoreSales.csv")
pf_sales.info()
pf_sales.head()

# %%
pf_details = pd.read_csv("StoreDetail.csv")
pf_details.info()
pf_details.head()

# %%
pf_G = pd.read_csv("ProductCategories.csv")
pf_G.info()
pf_G.head()

# %%
pf_Pr = pd.read_csv("Products.csv")
pf_Pr.info()
pf_Pr.head()

# %% [markdown]
# ## Core Marketing Analysis

# %% [markdown]
# ## Looking for territory manager and store location base on states Maryland and New jersery

# %%
n_store_states = ['New Jersey', 'Maryland']

n_stores = pf_details[pf_details['State'].isin(n_store_states )]

n_stores[['State', 'Territory Manager', 'Store ID', 'Store Location']].sort_values('State')

# %% [markdown]
# ## How many transactions the states have in total and total revenue per territory ( Maryland vs New Jersey)¶

# %%
maryland_ids = n_stores [n_stores['State']== "Maryland"]['Store ID']

maryland_sales = pf_sales[pf_sales['Store ID'].isin(maryland_ids)]

print(maryland_sales['Store ID'].unique())
print(maryland_sales.shape)

# %%
nj_ids = n_stores [n_stores['State']== "New Jersey"]['Store ID']

nj_sales = pf_sales[pf_sales['Store ID'].isin(nj_ids)]

print(nj_sales['Store ID'].unique())
print(nj_sales.shape)

# %%
# Total transaction from both of the stores

all_my_sales = pd.concat([maryland_sales, nj_sales]).copy()

print(total_sales_mn['Store ID'].unique()) 
print(total_sales_mn.shape)

# %%
# Build territory summary

# Dictionary to bild the table before putting it on pandas
summary = {
    'Territory'         : ['Maryland', 'New Jersey'],
    'Total Transactions': [len(maryland_sales), len(nj_sales)],
    'Total Revenue'     : [maryland_sales['Sale Amount'].sum(),  nj_sales['Sale Amount'].sum()]
}

# Making the DataFrame
summary_df = pd.DataFrame(summary)

# Format the numbers to look clean
summary_df['Total Transactions'] = summary_df['Total Transactions'].apply(lambda x: f"{x:,}")
summary_df['Total Revenue'] = summary_df['Total Revenue'].apply(lambda x: f"${x:,.2f}")

summary_df

# %%
# Group by Territory + Year + Month
# Then sum the Sale Amount for each group
monthly_revenue = all_my_sales.groupby(
    ['Territory', 'Year', 'Month', 'Store ID'], as_index=False)['Sale Amount'].agg(
    Total_Revenue='sum'
).sort_values(['Territory', 'Year', 'Month'])

monthly_revenue
